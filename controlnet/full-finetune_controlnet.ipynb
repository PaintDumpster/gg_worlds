# %%
training_args = ControlNetTrainingArguments(
    ...
    validation_image="./sample_topo.png",           # ← YOUR image path here
    validation_prompt="dense street layout over terrain",  # ← Matching prompt
    ...
)
